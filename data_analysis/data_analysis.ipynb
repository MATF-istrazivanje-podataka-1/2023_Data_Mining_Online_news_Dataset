# %%
import pandas as pd
import numpy as np
from statistics import median
from matplotlib import pyplot as plt
import seaborn as sns
from scipy import stats
from sklearn.model_selection import train_test_split
from copy import deepcopy
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
data = pd.read_csv('./../data/OnlineNewsPopularity.csv')
data
# Out:
#                                                      url   timedelta
# 0      http://mashable.com/2013/01/07/amazon-instant-...       731.0  \
# 1      http://mashable.com/2013/01/07/ap-samsung-spon...       731.0
# 2      http://mashable.com/2013/01/07/apple-40-billio...       731.0
# 3      http://mashable.com/2013/01/07/astronaut-notre...       731.0
# 4       http://mashable.com/2013/01/07/att-u-verse-apps/       731.0
# ...                                                  ...         ...
# 39639  http://mashable.com/2014/12/27/samsung-app-aut...         8.0
# 39640  http://mashable.com/2014/12/27/seth-rogen-jame...         8.0
# 39641  http://mashable.com/2014/12/27/son-pays-off-mo...         8.0
# 39642     http://mashable.com/2014/12/27/ukraine-blasts/         8.0
# 39643  http://mashable.com/2014/12/27/youtube-channel...         8.0
#
#         n_tokens_title   n_tokens_content   n_unique_tokens
# 0                 12.0              219.0          0.663594  \
# ...

# %%
data.describe()
# Out:
#           timedelta   n_tokens_title   n_tokens_content   n_unique_tokens
# count  39644.000000     39644.000000       39644.000000      39644.000000  \
# mean     354.530471        10.398749         546.514731          0.548216
# std      214.163767         2.114037         471.107508          3.520708
# min        8.000000         2.000000           0.000000          0.000000
# 25%      164.000000         9.000000         246.000000          0.470870
# 50%      339.000000        10.000000         409.000000          0.539226
# 75%      542.000000        12.000000         716.000000          0.608696
# max      731.000000        23.000000        8474.000000        701.000000
#
#         n_non_stop_words   n_non_stop_unique_tokens     num_hrefs
# count       39644.000000               39644.000000  39644.000000  \
# mean            0.996469                   0.689175     10.883690
# std             5.231231                   3.264816     11.332017
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39644 entries, 0 to 39643
# Data columns (total 61 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   url                             39644 non-null  object
#  1    timedelta                      39644 non-null  float64
#  2    n_tokens_title                 39644 non-null  float64
#  3    n_tokens_content               39644 non-null  float64
#  4    n_unique_tokens                39644 non-null  float64
#  5    n_non_stop_words               39644 non-null  float64
#  6    n_non_stop_unique_tokens       39644 non-null  float64
#  7    num_hrefs                      39644 non-null  float64
#  8    num_self_hrefs                 39644 non-null  float64
#  9    num_imgs                       39644 non-null  float64
#  10   num_videos                     39644 non-null  float64
#  11   average_token_length           39644 non-null  float64
# ...

# %%
data.isna().any().any()
# Out:
# False

# %%
data.drop('url', axis = 1, inplace = True)

# %%
df = pd.DataFrame(data)
correlation_matrix = df.corr()
correlation_matrix.to_csv('correlation_matrix.csv')

# %%
Y = data[' shares']
print('Average value: ' + str((sum(Y) / len(Y))))
print('Median: ' + str(median(Y)))
# Out:
# Average value: 3395.3801836343455
# Median: 1400.0

# %%
Y = [1 if i > 1400 else 0 for i in Y]
ones = Y.count(1)
zeroes = Y.count(0)
print('Number of ones: ' + str(ones))
print('Number of zeroes: ' + str(zeroes))
# Out:
# Number of ones: 19562
# Number of zeroes: 20082

# %%
sizes = [zeroes / len(Y), ones / len(Y)]
labels = ['Not popular', 'Popular']
fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels = labels, autopct = '%1.1f%%', startangle = 90)
plt.show()

# %%
data = data.drop(' shares', axis = 1)
X = data

# %%
for column in X.columns:
    plt.figure()
    plt.boxplot(X[column])
    plt.title(f'Boxplot for {column}')
    plt.xlabel('Values')
    plt.ylabel(column)
    plt.show()

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.25, random_state=42)

# %%
# %store X
# %store Y
# %store X_train
# %store X_test
# %store Y_train
# %store Y_test
# Out:
# Stored 'X' (DataFrame)
# Stored 'Y' (list)
# Stored 'X_train' (DataFrame)
# Stored 'X_test' (DataFrame)
# Stored 'Y_train' (list)
# Stored 'Y_test' (list)

# %%
#preuzeto sa vezbi
def IQR(data, feature_names):
    
    iqr = pd.DataFrame(0, index=feature_names, columns=['lower', 'min', 'num_lower', 'upper', 'max', 'num_upper', 'percantage'])
    
    for name in feature_names:
        (Q1, Q3) = data[name].quantile([0.25, 0.75])
        IQR = Q3 - Q1
        upper = Q3 + (1.5 * IQR)
        lower = Q1 - (1.5 * IQR)
        
        iqr.loc[name, 'upper'] = upper
        iqr.loc[name, 'lower'] = lower

        num_of_out_lower = (data[name] < lower).sum()
        num_of_out_upper = (data[name] > upper).sum()

        percentage = round((num_of_out_lower + num_of_out_upper) / X.shape[0] * 100)

        iqr.loc[name, 'num_lower'], iqr.loc[name, 'num_upper'], iqr.loc[name, 'percantage']  = num_of_out_lower, num_of_out_upper, percentage
        iqr.loc[name, 'min'], iqr.loc[name, 'max'] = min(X[name]), max(X[name])
    
    return iqr

# %%
iqr_train = IQR(X_train, X.columns)
iqr_test = IQR(X_test, X.columns)

# %%
iqr_train_lower = iqr_train['lower']
iqr_train_higher = iqr_train['upper']
iqr_test_lower = iqr_test['lower']
iqr_test_higher = iqr_test['upper']

# %%
X_train_iqr = deepcopy(X_train)
X_test_iqr = deepcopy(X_test)

for column in X_train.columns:
    low = iqr_train_lower[column]
    high = iqr_train_higher[column]
    X_train_iqr[column] = X_train_iqr[column].where(X_train_iqr[column] > low, low).where(X_train_iqr[column] < high, high)
    
for column in X_test.columns:
    low = iqr_test_lower[column]
    high = iqr_test_higher[column]
    X_test_iqr[column] = X_test_iqr[column].where(X_test_iqr[column] > low, low).where(X_test_iqr[column] < high, high)

# %%
#visual check that there are no outliers

for column in X_train_iqr.columns:
    plt.figure()
    plt.boxplot(X_train_iqr[column])
    plt.title(f'Boxplot for {column}')
    plt.xlabel('Values')
    plt.ylabel(column)
    plt.show()

# %%
# %store X_train_iqr
# %store X_test_iqr
# Out:
# Stored 'X_train_iqr' (DataFrame)
# Stored 'X_test_iqr' (DataFrame)

# %%
scaler = StandardScaler()
scaler.fit(X_train)
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
pca = PCA(n_components = 2)
pca.fit(X_train_scaled)
# Out:
# PCA(n_components=2)

# %%
pca.components_.shape
# Out:
# (2, 59)

# %%
pca_names = [f'Principal_component_{i}' for i in range(pca.n_components_)]

# %%
plt.matshow(pca.components_)
plt.xticks(ticks=range(pca.components_.shape[1]),
           labels=X.columns,
           rotation='vertical')
plt.yticks(ticks=range(pca.n_components_),
           labels=pca_names)
plt.colorbar()
plt.show()

# %%
X_train_pca = pca.transform(X_train.values)
X_test_pca = pca.transform(X_test.values)

# %%
# %store X_train_pca
# %store X_test_pca
# Out:
# Stored 'X_train_pca' (ndarray)
# Stored 'X_test_pca' (ndarray)
